# %%
import pandas as pd

# %%
df=pd.read_csv("iris.csv")

# %%
print(df)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#shape of dataset
print(df.shape)
# Out:
# (150, 6)

# %%
#heads
print(df.head)
# Out:
# <bound method NDFrame.head of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
#tail
df.tail
# Out:
# <bound method NDFrame.tail of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
df.iloc[25]     #indexlocator
# Out:
# Id                        26
# SepalLengthCm            5.0
# SepalWidthCm             3.0
# PetalLengthCm            1.6
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 25, dtype: object

# %%
df[0:25]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df[125:151]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 125  126            7.2           3.2            6.0           1.8
# 126  127            6.2           2.8            4.8           1.8
# 127  128            6.1           3.0            4.9           1.8
# 128  129            6.4           2.8            5.6           2.1
# 129  130            7.2           3.0            5.8           1.6
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 132  133            6.4           2.8            5.6           2.2
# 133  134            6.3           2.8            5.1           1.5
# 134  135            6.1           2.6            5.6           1.4
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# ...

# %%
df[30:61]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 30  31            4.8           3.1            1.6           0.2
# 31  32            5.4           3.4            1.5           0.4
# 32  33            5.2           4.1            1.5           0.1
# 33  34            5.5           4.2            1.4           0.2
# 34  35            4.9           3.1            1.5           0.1
# 35  36            5.0           3.2            1.2           0.2
# 36  37            5.5           3.5            1.3           0.2
# 37  38            4.9           3.1            1.5           0.1
# 38  39            4.4           3.0            1.3           0.2
# 39  40            5.1           3.4            1.5           0.2
# 40  41            5.0           3.5            1.3           0.3
# 41  42            4.5           2.3            1.3           0.3
# 42  43            4.4           3.2            1.3           0.2
# ...

# %%
df.iloc[1:30,1:3]   #df.iloc[rowstart:rowstop,colstart:colstop]
# Out:
#     SepalLengthCm  SepalWidthCm
# 1             4.9           3.0
# 2             4.7           3.2
# 3             4.6           3.1
# 4             5.0           3.6
# 5             5.4           3.9
# 6             4.6           3.4
# 7             5.0           3.4
# 8             4.4           2.9
# 9             4.9           3.1
# 10            5.4           3.7
# 11            4.8           3.4
# 12            4.8           3.0
# 13            4.3           3.0
# 14            5.8           4.0
# 15            5.7           4.4
# 16            5.4           3.9
# 17            5.1           3.5
# 18            5.7           3.8
# 19            5.1           3.8
# 20            5.4           3.4
# 21            5.1           3.7
# 22            4.6           3.6
# 23            5.1           3.3
# 24            4.8           3.4
# 25            5.0           3.0
# 26            5.0           3.4
# 27            5.2           3.5
# 28            5.2           3.4
# ...

# %%
df.iloc[-25:,]       #negative slicing
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 125  126            7.2           3.2            6.0           1.8
# 126  127            6.2           2.8            4.8           1.8
# 127  128            6.1           3.0            4.9           1.8
# 128  129            6.4           2.8            5.6           2.1
# 129  130            7.2           3.0            5.8           1.6
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 132  133            6.4           2.8            5.6           2.2
# 133  134            6.3           2.8            5.1           1.5
# 134  135            6.1           2.6            5.6           1.4
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# ...

# %%
df.isnull().sum()      #sum of all null values from dataset
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
f = df.drop_duplicates(subset = 'Species')
print(f)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 50    51            7.0           3.2            4.7           1.4
# 100  101            6.3           3.3            6.0           2.5
#
#              Species
# 0        Iris-setosa
# 50   Iris-versicolor
# 100   Iris-virginica

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=df['SepalLengthCm'],y=df['SepalWidthCm'],color='r',marker="*")
plt.title('Scatter Plot')
plt.show()

# %%
plt.scatter(x=df['PetalLengthCm'],y=df['PetalWidthCm'],color='r',marker="*")
plt.title('Scatter Plot')
plt.show()

# %%
import seaborn as sns

# %%
sns.countplot(x='Species',data=df)
plt.show()

# %%
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',hue='Species',data=df)
plt.legend(bbox_to_anchor=(1,1),loc=8)      #bbox is use to box outside of the graph
plt.show()

# %%
sns.pairplot(df.drop(['Id'],axis=1),hue='Species',height=2,data=df)
plt.show()

# %%
sns.boxplot(x='SepalLengthCm',data=df)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm'>

# %%
sns.boxplot(x='Species',y='PetalLengthCm',data=df)    #boxplot gives mean,median,1st quartile,3rd quaartile,min,max,outliers
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
import numpy as np

# %%
x=np.mean(df['PetalLengthCm'])
print(x)
# Out:
# 3.7586666666666693

# %%
x=np.median(df['PetalLengthCm'])
print(x)
# Out:
# 4.35

# %%
#standard deviation
x=np.std(df['PetalLengthCm'])
print(x)
# Out:
# 1.7585291834055201

# %%
#Quartiles
x = np.quantile(df['SepalLengthCm'], [0,0.25,0.5,0.75,1])
print(x)
# Out:
# [4.3 5.1 5.8 6.4 7.9]

# %%
#percentile
x = np.percentile(df['PetalWidthCm'],[20,40,50,60,70])
print(x)
# Out:
# [0.2  1.16 1.3  1.5  1.8 ]

# %%
#variance
x=np.var(df['PetalLengthCm'])
print(x)
# Out:
# 3.0924248888888854

# %% [markdown]
# 1.LOGISTIC REGRESSION

# %%
#Importing Logistic Regression model
from sklearn.linear_model import LogisticRegression

# %%
lr= LogisticRegression()

# %%
#Training and Testing data

X = df[["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]]
y = df['Species']

#Importing "train_test-split" function to test the model
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=40)

# %%
X_train.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 39             5.1           3.4            1.5           0.2
# 118            7.7           2.6            6.9           2.3
# 138            6.0           3.0            4.8           1.8
# 75             6.6           3.0            4.4           1.4
# 37             4.9           3.1            1.5           0.1

# %%
print("Train dataset shape is", X_train.shape)
print("Test dataset shape is", X_test.shape)
# Out:
# Train dataset shape is (105, 4)
# Test dataset shape is (45, 4)

# %%
#Fit the model in train and test data
lr.fit(X_train,y_train).score(X_train,y_train)
# Out:
# 0.9809523809523809

# %%
#Now fitting the model in test set
prediction=lr.predict(X_test)

# %%
#Printing first 5 rows after fitting the model in test set
print (X_test.head())
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 38             4.4           3.0            1.3           0.2
# 66             5.6           3.0            4.5           1.5
# 115            6.4           3.2            5.3           2.3
# 117            7.7           3.8            6.7           2.2
# 89             5.5           2.5            4.0           1.3

# %%
from sklearn import metrics
cm = metrics.confusion_matrix(y_test, prediction) 
print(cm)
accuracy = metrics.accuracy_score(y_test, prediction) 
print("Accuracy score:",accuracy)
# Out:
# [[16  0  0]
#  [ 0 14  0]
#  [ 0  0 15]]
# Accuracy score: 1.0

# %%
2.SVM

# %%
#SVM
from sklearn.svm import SVC

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['Species']=encoder.fit_transform(df['Species'])

# %%
model=SVC()
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
#creating the predictions on the test data i.e. X_test
y_pred =model.predict(X_test)
y_pred
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(y_test, y_pred)
print("Accuracy for the SVM Classifier: {:.3f}".format(accuracy))
# Out:
# Accuracy for the SVM Classifier: 1.000

# %%
3.Random Forest

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=200)
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
predictions = rfc.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       1.00      1.00      1.00        14
#  Iris-virginica       1.00      1.00      1.00        15
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
